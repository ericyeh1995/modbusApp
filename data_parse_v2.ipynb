 0, 0, 17287, 0, 17056, 0, 17056, 0, 17234, 0, 16928, 0, 16928, 0, 16672, 0, 17056, 0, 0, 0, 17008, 0, 16211, 55827, 0, 0, 0, 0, 18706, 31744, 17587, 4066, 17943, 0]
data_8 = [9472, 37908, 20, 0, 0, 0, 625, 1025, 768, 33796, 49152, 0, 0, 0, 0, 0, 1400, 6738, 1520, 313, 1400, 539, 1400, 62, 1050, 65533, 1400, 5, 15000, 4669, 155, 91, 0, 0, 0, 0, 0, 0, 0, 0, 59, 0, 33, 0, 0, 0, 0, 0, 1, 0, 1505, 1610, 1651, 1750, 1756, 1751, 262, 262, 277, 366, 382, 378, 1854, 1944, 32767, 0, 1854, 16, 30, 0, 0, 17287, 0, 17056, 0, 17056, 0, 17234, 0, 16928, 0, 16928, 0, 16974, 0, 17046, 0, 0, 0, 17008, 0, 17185, 56396, 17988, 11366, 17762, 54117, 18706, 31744, 17587, 17432, 17943, 0]

# %%
def decimals_to_float32(int1, int2):
    """Convert to float
    
    Note:
        Orders in big endian
    Args:
        int1, int2 (int)
    Return:
        float: decoded value
    """
    f = int('{:016b}{:016b}'.format(int1, int2), 2)
    return struct.unpack('f', struct.pack('I', f))[0]


def unpack_bool(data):
    """Extract list of boolean from integer
    
    Args:
        data (int)
    Return:
        list: in bool
    """
    return [bool(int(i)) for i in '{:016b}'.format(data)]

def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0:
        val = val - (1 << bits)
    return val

# %%
# create a parsing dictionary

tags = OrderedDict()
with open('plc_tags.csv', 'r') as f:
    reader = csv.reader(f, doublequote=True, quoting=csv.QUOTE_ALL, escapechar='\\')
    header = next(reader)
    header[0] = 'Name' # manually adjust from \ufeffName to Name
    tags = {row[0]:{header[i]:row[i] for i in range(0,len(header))} for row in reader}

print(json.dumps(tags, indent=4))
# Out:
# {
#     "PIW0": {
#         "Name": "PIW0",
#         "Data Type": "Word",
#         "Logical Address": "%QW500",
#         "scale": "",
#         "mapping": "DIW0"
#     },
#     "PIW2": {
#         "Name": "PIW2",
#         "Data Type": "Word",
#         "Logical Address": "%QW502",
#         "scale": "",
#         "mapping": "DIW2"
#     },
#     "PIW4": {
#         "Name": "PIW4",
#         "Data Type": "Word",
#         "Logical Address": "%QW504",
#         "scale": "",
#         "mapping": "DIW4"
#     },
#     "PIW6": {
#         "Name": "PIW6",
#         "Data Type": "Word",
#         "Logical Address": "%QW506",
#         "scale": "",
#         "mapping": "DIW6"
#     },
#     "PIW20": {
#         "Name": "PIW20",
#         "Data Type": "Word",
#         "Logical Address": "%QW508",
#         "scale": "",
#         "mapping": "DIW20"
#     },
#     "PIW30": {
#         "Name": "PIW30",
#         "Data Type": "Word",
#         "Logical Address": "%QW510",
# ...

# %%
# process data

data_iter = iter(data_8)
for tag in tags:
    val = next(data_iter)
    
    if tags[tag]["Data Type"] == "Real":
        val = decimals_to_float32(val, next(data_iter))
        
    elif tags[tag]["Data Type"] == "Word":
        pass
    
    elif tags[tag]["Data Type"] == "Int":
        val = twos_comp(val, 16)
        
    if tags[tag]['scale'] == 'x10':
        val /= 10
        
    tags[tag]['value'] = val
print(json.dumps(tags, indent=4))
# Out:
# {
#     "PIW0": {
#         "Name": "PIW0",
#         "Data Type": "Word",
#         "Logical Address": "%QW500",
#         "scale": "",
#         "mapping": "DIW0",
#         "value": 9472
#     },
#     "PIW2": {
#         "Name": "PIW2",
#         "Data Type": "Word",
#         "Logical Address": "%QW502",
#         "scale": "",
#         "mapping": "DIW2",
#         "value": 37908
#     },
#     "PIW4": {
#         "Name": "PIW4",
#         "Data Type": "Word",
#         "Logical Address": "%QW504",
#         "scale": "",
#         "mapping": "DIW4",
#         "value": 20
#     },
#     "PIW6": {
#         "Name": "PIW6",
#         "Data Type": "Word",
#         "Logical Address": "%QW506",
#         "scale": "",
#         "mapping": "DIW6",
#         "value": 0
#     },
#     "PIW20": {
#         "Name": "PIW20",
#         "Data Type": "Word",
#         "Logical Address": "%QW508",
#         "scale": "",
#         "mapping": "DIW20",
#         "value": 0
#     },
# ...

# %%
# reduce

formatted_data = {tag:tags[tag]['value'] for tag in tags if tags[tag]['Data Type'] != "Word"}
print(json.dumps(formatted_data, indent=4))
# Out:
# {
#     "Mtr_Ex1_rpm_max": 140.0,
#     "Mtr_Ex1_rpm_disp": 673.8,
#     "Mtr_Ex1_amp_max": 152.0,
#     "Mtr_Ex1_amp_disp": 31.3,
#     "Mtr_Ex1_screw_rpm_max": 140.0,
#     "Mtr_Ex1_screw_rpm_disp": 53.9,
#     "Mtr_Ex2_rpm_max": 140.0,
#     "Mtr_Ex2_rpm_disp": 6.2,
#     "Mtr_Ex2_amp_max": 105.0,
#     "Mtr_Ex2_amp_disp": -0.3,
#     "Mtr_Ex2_screw_rpm_max": 140.0,
#     "Mtr_Ex2_screw_rpm_disp": 0.5,
#     "Mtr_Cap_rpm_max": 1500.0,
#     "Mtr_Cap_rpm_disp": 466.9,
#     "Mtr_Cap_amp_max": 15.5,
#     "Mtr_Cap_amp_disp": 9.1,
#     "Dia_H_Xdisp": 0.0,
#     "Dia_H_Ydisp": 0.0,
#     "Dia_H_OD_Set": 0.0,
#     "Dia_H_ID_Set": 0.0,
#     "Dia_H_Tol_max": 0.0,
#     "Dia_H_Tol_min": 0.0,
#     "Dia_H_Status": 0,
#     "Dia_C_X_Set": 0.0,
#     "Dia_C_Xdisp": 5.9,
#     "Dia_C_Y_Set": 0.0,
#     "Dia_C_Ydisp": 3.3,
#     "Dia_C_OD_Set": 0.0,
#     "Dia_C_ID_Set": 0.0,
#     "Dia_C_Tol_max": 0.0,
#     "Dia_C_Tol_min": 0.0,
#     "Dia_C_Status": 0,
#     "Dia_C_CableType": 1,
# ...

# %%
# index data to ES

# %% [markdown]
# # scrap area

# %%
f = int('{:016b}{:016b}'.format(12, 12), 2)
print(f)
struct.unpack('f', struct.pack('I', f))[0]
# Out:
# 786444
# 1.1020427694774664e-39

# %%
import ctypes
number = 65534 & 0xFFFFFFFF
signed_number = ctypes.c_long(number).value
print(signed_number)
# Out:
# 65534

# %%
def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
        val = val - (1 << bits)        # compute negative value
    return val                         # return positive value as is

twos_comp(65534, 16)
# Out:
# -2

# %%
unpack_bool(65535)
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]
